# %% [markdown]
# <a href="https://colab.research.google.com/github/imaprooooo/Kursai/blob/main/ggs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1 = "string"
float1 = 6.7
int1 = 67
bool1 = True

print("rzeczy dla n00bków:")
print(f"string:{str1}, float:{float1}, int:{int1}, float:{float1}")
print()
print("--------------------")
print()
print(f"zmienna int1 jest typu:{type(int1)}")
print()
print("--------------------")
print()
lista_gier = ["mc","cs","fn"]
print(f"1 element z listy lista_gier:{lista_gier[0]}")
lista_gier.append("stardew valley")
print()
print("--------------------")
print()
print(f"lista_gier po dodaniu elementu:{lista_gier}")

# %%
print("pętle:DDD")
print("--------------------")
licznik = 0
print("pętla while:")
while licznik<=5:
  print(f"licznik:{licznik}")
  licznik+=1
print()
print("--------------------")
print()
print("pętla for:")
for i in range(6):
  print(i)
